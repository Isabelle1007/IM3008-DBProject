# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
url = "https://hahow.in/courses"

# %%
re = requests.get(url)
soup = BeautifulSoup(re.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="zh-TW">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1,viewport-fit=cover" name="viewport"/>
#   <meta content="85be3689f02516040edbcaa21c56777c" name="p:domain_verify"/>
#   <meta content="DLABtQBZUS1eHOn-qLPmqKea3NuVlzY3PF2ZjBR5LmE" name="google-site-verification"/>
#   <meta content="1635235061-df0552a" name="hahow-version"/>
#   <title>
#    Hahow 好學校 | 最有趣的線上課程平台 | 自學那些學校沒教的事
#   </title>
#   <link href="https://hahow.in/favicon.ico" rel="shortcut icon"/>
#   <link href="https://hahow.in/highres-icon.png" rel="apple-touch-icon"/>
#   <link href="https://hahow.in/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="https://hahow.in/website_icon.svg" rel="mask-icon"/>
# ...
