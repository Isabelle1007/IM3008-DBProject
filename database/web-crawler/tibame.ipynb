# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
url = "https://www.tibame.com/courselibrary"

# %%
re = requests.get(url)
soup = BeautifulSoup(re.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <style data-styled="true" data-styled-version="5.2.1">
#  .fxLvDw{width:72px;height:58px;background-repeat:no-repeat;background-image:url(https://cdn-static.tibame.com/staticImages/recruit/recruit-default.svg);background-size:contain;-webkit-transition:all 0.3s ease;transition:all 0.3s ease;background-position:0 -5px;cursor:pointer;margin-left:-16px;margin-right:12px;}/*!sc*/
# .fxLvDw:hover{background-image:url(https://cdn-static.tibame.com/staticImages/recruit/recruit-hover.svg);background-position:0 -2px;}/*!sc*/
# data-styled.g51[id="AppToCNavBar__Recruit-cmpgkd-0"]{content:"fxLvDw,"}/*!sc*/
# .fbHtWf{width:100%;height:330px;background-image:url('https://cdn-static.tibame.com/defaultImages/course-library/online-course-banner-1920@1x.png');background-size:cover;background-position:center;background-repeat:no-repeat;}/*!sc*/
# data-styled.g131[id="Jumbotron__BackgroundCover-sc-1v6dn3p-3"]{content:"fbHtWf,"}/*!sc*/
# .ediuWk{outline:0;}/*!sc*/
# ...
